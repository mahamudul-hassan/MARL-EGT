# %% [markdown]
# # Generic $N$-Player Hierarchical MARL Framework — **SAC branch**
#
# This notebook is the **SAC-only** half of the original combined notebook, split so the
# SAC outer-loop search and the Bayesian-optimization (BO) baseline can be run
# **simultaneously in two separate notebooks/kernels** (e.g. two Colab runtimes, or two
# local Jupyter kernels), instead of sequentially in one notebook.
#
# Contains: game definition, payoff tensor, agent networks, inner-loop PPO, outer-loop
# reward, the SAC meta-optimizer, replicator + numerical-Jacobian validation, the SAC run,
# SAC validation, the inner-loop trajectory/cycling check (Section 15, built on the SAC
# results), and the wall-clock scaling benchmark (Section 16, optimizer-independent).
#
# Run top to bottom independently of the BO notebook. Both write CSVs to
# `./results_5player/`; see the note at the end of this notebook for combining results
# into the SAC-vs-BO comparison table afterward.

# %% [markdown]
# # Generic $N$-Player Hierarchical MARL Framework for High-Dimensional Evolutionary Games
# ### Larger-scale validation for the IJPR revision (Reviewer 1.1 / 1.2 / 1.3 and Reviewer 3 major #1)
#
# This notebook generalizes the three-player framework to **any number of players, each with any number of strategies**, and applies it to a **five-player, multi-strategy supply-chain quality-governance game** whose joint strategy space ($3\times4\times3\times4\times4 = 576$ pure profiles, a $13\times 13$ Jacobian) is far beyond hand analysis.
#
# **What is preserved from the original code (so results stay comparable and fast):**
# - the independent-PPO **inner loop** implemented with `jax.lax.scan` over episodes,
# - **`jax.vmap`** over the agent axis (this is what replaces the three hard-coded reward functions with one generic vectorized update),
# - **`jax.jit`** compilation of the whole inner loop,
# - **Gumbel-argmax** action sampling,
# - the SAC-style **outer loop** that proposes game parameters,
# - validation by **forward replicator simulation** and a **numerical Jacobian** (the two checks that survive when no closed-form Jacobian exists).
#
# **What is new:** the game is defined by a data-driven **payoff tensor** of shape `(n_players, k_1, ..., k_N)` built from economically meaningful parameters, and a per-agent **valid-strategy mask** so players can have different strategy counts. Nothing about the acceleration structure changes.
#
# > **Note on early stopping.** Following Reviewer 3 (major #4), early stopping is now an **explicit boolean flag** (`use_early_stopping`). In all reported runs it is **disabled** (we run the full epoch budget), which is why the original patience was set to a large number. Both behaviours are now standard and documented.

# %% [markdown]
# ## 1. Imports and global configuration
# Standard JAX / Optax / NumPy stack. We set 64-bit precision off (32-bit is faster on GPU and sufficient here) and fix a master seed for reproducibility.

# %%
import jax, jax.numpy as jnp
from jax import lax
from functools import partial
import numpy as np
import pandas as pd
import itertools, time, os
from scipy.integrate import solve_ivp

MASTER_SEED = 42
np.random.seed(MASTER_SEED)
print("JAX", jax.__version__, "| devices:", jax.devices())
# Out:
# JAX 0.10.1 | devices: [CpuDevice(id=0)]

# %% [markdown]
# ### 1b. Run configuration and output folders
#
# One switch, `PAPER_SCALE`, toggles between a fast CPU demo and the full paper-scale run. **Every experiment writes its results to CSV** under `./results_5player/`, so you can re-run any single block, hand the CSVs back, and the figures/tables can be regenerated without re-running the search. Set `PAPER_SCALE = True` on a GPU machine (Colab is fine) to produce the numbers reported in the paper.
#
# The paper-scale values are taken **directly from the original E3/E4/E7/E8 notebooks' executed calls**, so the larger game is run under the same protocol as the small game: `n_runs = 100`, outer epochs `= 200`, inner PPO episodes `= 3000`, `patience = 1000` (early stopping effectively disabled, i.e. the full outer budget always runs), validation seeds `= 5`, warmup `= 5`.
#
# - Demo (`PAPER_SCALE=False`): a handful of runs, short budgets, finishes in minutes on CPU.
# - Paper (`PAPER_SCALE=True`): the settings above; run on a GPU.

# %%
PAPER_SCALE = True   # <--- set True on GPU for the reported numbers

# Paper-scale settings match the actual calls in the original E3/E4/E7/E8 notebooks:
#   n_runs=100, n_epochs(outer)=200, ppo_episodes(inner)=3000,
#   patience=1000 (early stopping effectively disabled), n_val_seeds=5, warmup_epochs=5.
if PAPER_SCALE:
    CFG = dict(N_RUNS=100, N_OUTER=200, N_EPISODES=3000,
               N_VAL_STARTS=5, PATIENCE=1000, WARMUP=5)
else:
    CFG = dict(N_RUNS=8,   N_OUTER=12,  N_EPISODES=800,
               N_VAL_STARTS=12, PATIENCE=1000, WARMUP=5)

OUTDIR = "results_5player"
os.makedirs(OUTDIR, exist_ok=True)
def save_csv(df, name):
    path = os.path.join(OUTDIR, name)
    df.to_csv(path, index=False)
    print(f"  saved -> {path}  ({len(df)} rows)")
    return path
print("PAPER_SCALE =", PAPER_SCALE, "| config:", CFG)
# Out:
# PAPER_SCALE = True | config: {'N_RUNS': 100, 'N_OUTER': 200, 'N_EPISODES': 3000, 'N_VAL_STARTS': 5, 'PATIENCE': 1000, 'WARMUP': 5}

# %% [markdown]
# ## 2. Game specification: a five-player supply-chain quality-governance game
#
# This is a genuine multi-tier generalization of the three-player e-commerce model, with a **variable number of strategies per player (3 or 4)** as required. The tiers are:
#
# | # | Player | Strategies ($k$) | Meaning |
# |---|--------|------------------|---------|
# | 1 | **Supplier** | 3: high / standard / substandard | input grade |
# | 2 | **Manufacturer** | 4: full-QC / partial-QC / minimal-QC / no-QC | internal quality-control effort |
# | 3 | **Inspector** (buyer-side QC) | 3: strict / sampling / slack | incoming inspection intensity |
# | 4 | **Distributor / retailer** | 4: accept / re-inspect / return / recall | lot decision on the received batch |
# | 5 | **Regulator / certifier** | 4: high / medium / low / no audit | external oversight and penalties |
#
# The joint pure-strategy space is $3\times4\times3\times4\times4 = 576$ profiles; the reduced replicator system is **13-dimensional**, and its Jacobian at each of the $576$ corners is a $13\times13$ symbolic matrix. By Abel–Ruffini the eigenvalue conditions have no general closed form, so this instance is **analytically intractable by hand**, which is exactly the regime the framework targets. (The original published model has 3 players, 2 strategies each: 8 profiles and a $3\times3$ Jacobian.)
#
# **Economic logic (payoffs are not random).** A unit's genuine quality $q$ is the product of the supplier-grade quality and the manufacturer-effort quality. A defect ($1-q$) is caught with probability determined jointly by the inspector, distributor, and regulator (a complementary detection cascade). A **caught** defect triggers penalties on the upstream players; an **escaped** defect triggers reputation loss $W$, buyer disutility $B$, and downstream losses. Each player pays its own action cost. This produces the same structural tension as the small game (cutting quality saves cost but risks penalty and reputation), now across five interacting tiers with finer-grained strategy choices.

# %%
# ---- strategy labels (VARIABLE count per player: 3 or 4) ----
STRAT = {
 'supplier':    ['high','standard','sub'],                     # 3
 'manufacturer':['fullQC','partQC','minQC','noQC'],            # 4
 'inspector':   ['strict','sampling','slack'],                 # 3
 'distributor': ['accept','reinspect','return','recall'],      # 4
 'regulator':   ['auditH','auditM','auditL','noAudit'],        # 4
}
PLAYERS   = list(STRAT.keys())
N_PLAYERS = len(PLAYERS)
STRAT_COUNTS = [len(STRAT[p]) for p in PLAYERS]
K_MAX = max(STRAT_COUNTS)
print("players:", PLAYERS)
print("strategy counts:", STRAT_COUNTS, "| K_max:", K_MAX)
print("joint pure profiles:", int(np.prod(STRAT_COUNTS)))
print("reduced Jacobian dimension:", sum(k-1 for k in STRAT_COUNTS))

# valid-strategy mask: 1 where a strategy exists, 0 where padded to K_MAX
VALID_MASK = np.zeros((N_PLAYERS, K_MAX))
for i,k in enumerate(STRAT_COUNTS):
    VALID_MASK[i,:k] = 1.0
VALID_MASK = jnp.array(VALID_MASK)
# Out:
# players: ['supplier', 'manufacturer', 'inspector', 'distributor', 'regulator']
# strategy counts: [3, 4, 3, 4, 4] | K_max: 4
# joint pure profiles: 576
# reduced Jacobian dimension: 13

# %% [markdown]
# ## 3. Parameter space $\theta$ and bounds
#
# The outer loop searches over the economic parameters below (the analogue of the 13-dimensional $\theta$ in the small game, now 21-dimensional). Bounds are chosen to keep costs ordered (`Cs_h > Cs_s > Cs_b`, etc.) and economically sensible. As in the original framework, **no eigenvalue information ever enters the search** (that would be data leakage and is unavailable at scale).

# %%
PARAM_NAMES = ['P','Cs_h','Cs_s','Cs_b','Cm_f','Cm_p','Cm_m','Cm_n',
               'Ci_s','Ci_p','Ci_0','Ca_h','Ca_m','Ca_l','Cd_r','Cd_ret','Cd_rec',
               'W','B','F_m','F_s','I','R_p','R_c','Vq','G','Sc']
# Wider, economically-ordered bounds. Vq/G/Sc are incentive levers that make quality
# and monitoring individually rational (without them no good-governance ESS can exist).
PARAM_BOUNDS = {
 'P':(120,450),'Cs_h':(60,140),'Cs_s':(35,95),'Cs_b':(12,55),
 'Cm_f':(35,110),'Cm_p':(20,75),'Cm_m':(10,50),'Cm_n':(3,28),
 'Ci_s':(20,90),'Ci_p':(8,45),'Ci_0':(1,15),
 'Ca_h':(20,90),'Ca_m':(12,55),'Ca_l':(5,30),
 'Cd_r':(5,40),'Cd_ret':(12,60),'Cd_rec':(25,95),
 'W':(30,220),'B':(20,180),'F_m':(40,320),'F_s':(20,200),
 'I':(5,70),'R_p':(10,70),'R_c':(50,220),
 'Vq':(20,220),'G':(10,180),'Sc':(10,150),
}
N_PARAMS = len(PARAM_NAMES)
LOWER = jnp.array([PARAM_BOUNDS[n][0] for n in PARAM_NAMES])
UPPER = jnp.array([PARAM_BOUNDS[n][1] for n in PARAM_NAMES])
# Logical ordering constraints enforced by monotone repair after scaling:
#   P > Cs_h ; Cs_h>Cs_s>Cs_b ; Cm_f>Cm_p>Cm_m>Cm_n ; Ci_s>Ci_p>Ci_0 ;
#   Ca_h>Ca_m>Ca_l ; Cd_rec>Cd_ret>Cd_r
_ORDER_GROUPS = [['Cs_h','Cs_s','Cs_b'],['Cm_f','Cm_p','Cm_m','Cm_n'],
                 ['Ci_s','Ci_p','Ci_0'],['Ca_h','Ca_m','Ca_l'],
                 ['Cd_rec','Cd_ret','Cd_r']]
print("theta dimension:", N_PARAMS)
# Out:
# theta dimension: 27

# %% [markdown]
# ## 4. Building the payoff tensor from $\theta$
#
# `build_payoff_tensor(theta)` returns an array of shape `(N_PLAYERS, K_MAX, ..., K_MAX)` giving every player's payoff under every joint pure profile (padded strategies are masked). It is written with NumPy for clarity and then converted to a JAX array; it is called **once per outer step** (cheap: 576 profiles). This is the single function a user rewrites to define a different game; the entire MARL machinery downstream is game-agnostic.
#
# The detection cascade and quality composition make the tensor economically coherent rather than arbitrary.

# %%
Q_SUP = {'high':0.97,'standard':0.80,'sub':0.45}
Q_MFR = {'fullQC':0.97,'partQC':0.85,'minQC':0.70,'noQC':0.55}
D_INS = {'strict':0.85,'sampling':0.50,'slack':0.10}
D_DIS = {'accept':0.0,'reinspect':0.55,'return':0.85,'recall':1.0}
D_REG = {'auditH':0.55,'auditM':0.35,'auditL':0.18,'noAudit':0.0}
_A_LVL   = {'auditH':1.0,'auditM':0.6,'auditL':0.3,'noAudit':0.0}
_INS_LVL = {'strict':1.0,'sampling':0.55,'slack':0.15}

def build_payoff_tensor(th):
    c_sup={'high':th['Cs_h'],'standard':th['Cs_s'],'sub':th['Cs_b']}
    c_mfr={'fullQC':th['Cm_f'],'partQC':th['Cm_p'],'minQC':th['Cm_m'],'noQC':th['Cm_n']}
    c_ins={'strict':th['Ci_s'],'sampling':th['Ci_p'],'slack':th['Ci_0']}
    c_reg={'auditH':th['Ca_h'],'auditM':th['Ca_m'],'auditL':th['Ca_l'],'noAudit':0.0}
    c_dis={'accept':0.0,'reinspect':th['Cd_r'],'return':th['Cd_ret'],'recall':th['Cd_rec']}
    P,W,B=th['P'],th['W'],th['B']; Fm,Fs,I=th['F_m'],th['F_s'],th['I']
    Rp,Rc=th['R_p'],th['R_c']; Vq,G,Sc=th['Vq'],th['G'],th['Sc']
    payoff=np.zeros((N_PLAYERS,)+tuple([K_MAX]*N_PLAYERS))
    for idx in itertools.product(*[range(STRAT_COUNTS[i]) for i in range(N_PLAYERS)]):
        s,m,ins,dis,reg=[STRAT[PLAYERS[i]][idx[i]] for i in range(N_PLAYERS)]
        q=Q_SUP[s]*Q_MFR[m]; defect=1-q
        pdet=1-(1-D_INS[ins])*(1-D_DIS[dis])*(1-D_REG[reg])
        escaped=defect*(1-pdet); caught=defect*pdet
        qbonus=Vq*q                                   # market pays for realized quality
        sup = P + 0.5*qbonus - c_sup[s] - caught*Fs - escaped*0.5*W
        man = P + qbonus - c_mfr[m] - caught*Fm - escaped*W
        insp= Rp + Sc*_INS_LVL[ins] - c_ins[ins] + caught*0.3*Fm - escaped*B
        dist= Rc + 0.5*qbonus - c_dis[dis] - escaped*B + (I*defect if dis in ('return','recall') else 0)
        regu= G*_A_LVL[reg] - c_reg[reg] + caught*0.25*(Fm+Fs) - escaped*0.5*B
        payoff[(slice(None),)+idx]=[sup,man,insp,dist,regu]
    return jnp.array(payoff)

# quick check
_th={n:float((lo+hi)/2) for n,(lo,hi) in PARAM_BOUNDS.items()}
_pt=build_payoff_tensor(_th)
print("payoff tensor:", _pt.shape, "| entries:", _pt.size)
# Out:
# payoff tensor: (5, 4, 4, 4, 4, 4) | entries: 5120

# %% [markdown]
# ## 5. Agent networks, vectorized over the agent axis with `vmap`
#
# Instead of three named networks, we build **one stack of $N$ identical-shape MLPs** whose leaves carry a leading agent axis. `jax.vmap` then evaluates all agents in parallel. Each agent outputs `K_MAX` logits (padded strategies are masked to $-\infty$) and a scalar value baseline. This is the generic replacement for the per-agent policy/value nets in the original code, and it is what lets the same code serve any $N$ and any $k$.

# %%
WIDTH = 64
def init_agents(key, n_players, ctx_dim, k_max, width=WIDTH):
    keys = jax.random.split(key, n_players)
    def one(k):
        k1,k2,k3=jax.random.split(k,3)
        return dict(
            W1=jax.random.normal(k1,(ctx_dim,width))*jnp.sqrt(2/ctx_dim), b1=jnp.zeros(width),
            W2=jax.random.normal(k2,(width,k_max))*0.01, b2=jnp.zeros(k_max),
            Wv=jax.random.normal(k3,(width,1))*0.01, bv=jnp.zeros(1))
    return jax.vmap(one)(keys)

def agents_forward(params, ctx):
    def one(p):
        h=jnp.tanh(ctx @ p['W1'] + p['b1'])
        return h @ p['W2'] + p['b2'], (h @ p['Wv'] + p['bv'])[0]
    return jax.vmap(one)(params)   # (N,K_MAX), (N,)

def gumbel_argmax(key, logits, mask):
    g=-jnp.log(-jnp.log(jax.random.uniform(key,logits.shape)+1e-20)+1e-20)
    return jnp.argmax(jnp.where(mask>0, logits+g, -1e30))
print("networks defined")
# Out:
# networks defined

# %% [markdown]
# ## 6. Inner loop: independent PPO via `lax.scan` (jit-compiled)
#
# This is the heart of the framework and mirrors the original `run_ppo_episodes`: a single `lax.scan` over episodes, each step doing Gumbel-argmax action selection, a payoff lookup from the tensor, and one clipped-PPO update per agent (vectorized with `vmap`). The Adam state is carried in the scan `carry`, exactly as before, so the whole loop compiles to one fused kernel. The only structural change from the original is that the three explicit agents are now a single vmapped agent axis and the payoff comes from tensor indexing rather than three reward functions.

# %%
@partial(jax.jit, static_argnums=(6,7,8))
def run_inner(params, ctx, keys, payoff_tensor, valid_mask, target_probs,
              n_players, k_max, record_every, lr=3e-4, clip=0.2):
    def gather(actions):
        return payoff_tensor[(slice(None),)+tuple(actions[i] for i in range(n_players))]
    def step(carry, key):
        params,m,v,t=carry
        logits,vals=agents_forward(params,ctx)
        akeys=jax.random.split(key,n_players)
        actions=jax.vmap(gumbel_argmax)(akeys,logits,valid_mask)
        rewards=gather(actions)
        logp=jax.vmap(lambda l,a: jax.nn.log_softmax(l)[a])(logits,actions)
        adv=rewards-vals
        def loss(params):
            lg,vl=agents_forward(params,ctx)
            lp=jax.vmap(lambda l,a: jax.nn.log_softmax(l)[a])(lg,actions)
            r=jnp.exp(lp-logp); rc=jnp.clip(r,1-clip,1+clip)
            return -jnp.mean(jnp.minimum(r*adv,rc*adv))+0.5*jnp.mean((vl-rewards)**2)
        g=jax.grad(loss)(params)
        m=jax.tree_util.tree_map(lambda m,g:0.9*m+0.1*g,m,g)
        v=jax.tree_util.tree_map(lambda v,g:0.999*v+0.001*g*g,v,g)
        mh=jax.tree_util.tree_map(lambda m:m/(1-0.9**(t+1)),m)
        vh=jax.tree_util.tree_map(lambda v:v/(1-0.999**(t+1)),v)
        params=jax.tree_util.tree_map(lambda p,m,v:p-lr*m/(jnp.sqrt(v)+1e-8),params,mh,vh)
        probs=jax.vmap(lambda l,mm: jax.nn.softmax(jnp.where(mm>0,l,-1e30)))(logits,valid_mask)
        return (params,m,v,t+1),probs
    m0=jax.tree_util.tree_map(jnp.zeros_like,params)
    v0=jax.tree_util.tree_map(jnp.zeros_like,params)
    (params,_,_,_),hist=lax.scan(step,(params,m0,v0,0),keys)
    final=hist[-1]
    tail=hist[-record_every:]
    stab=jnp.mean(jnp.var(tail,axis=0))
    return final,stab,hist
print("inner loop compiled-ready")
# Out:
# inner loop compiled-ready

# %% [markdown]
# ## 7. Outer-loop reward
#
# The outer objective is unchanged in spirit: minimize a strategy-matching loss (cross-entropy between the inner loop's final profile and the target ESS) plus a stability penalty (tail variance), i.e. maximize its negative. The **SAC** outer loop from the main paper consumes this same scalar reward, so the larger game is solved with the identical method used for the small game.

# %%
def scale_action_to_theta(a01):
    # a01 in [0,1]^N_PARAMS -> physical parameters, then repair logical ordering.
    vals = np.array(LOWER) + np.array(a01)*(np.array(UPPER)-np.array(LOWER))
    th = {n: float(vals[i]) for i,n in enumerate(PARAM_NAMES)}
    # monotone repair: sort each cost tier so the ordering constraint always holds
    for grp in _ORDER_GROUPS:                      # grp is high->low
        sorted_vals = sorted((th[n] for n in grp), reverse=True)
        for n,v in zip(grp, sorted_vals): th[n]=v
    # price must exceed the highest input cost (P > Cs_h); lift if needed
    if th['P'] <= th['Cs_h']:
        th['P'] = th['Cs_h'] + 5.0
    return th

def outer_reward(theta_dict, target_probs, key, n_episodes=2000,
                 record_every=20, w_strategy=1.0, w_stability=0.5):
    payoff = build_payoff_tensor(theta_dict)
    params = init_agents(key, N_PLAYERS, CTX_DIM, K_MAX)
    keys = jax.random.split(key, n_episodes)
    final, stab, _ = run_inner(params, CTX, keys, payoff, VALID_MASK, target_probs,
                               N_PLAYERS, K_MAX, record_every)
    # strategy loss: BCE-style match to target on valid strategies
    eps=1e-7; fp=jnp.clip(final,eps,1-eps)
    strat_loss = -jnp.sum(VALID_MASK*(target_probs*jnp.log(fp)))
    return float(-(w_strategy*strat_loss + w_stability*stab)), np.array(final)

CTX_DIM = 6
CTX = jnp.ones(CTX_DIM)/2.0     # fixed context (stateless game); hook for multi-context extension
print("outer reward defined")
# Out:
# outer reward defined

# %% [markdown]
# ## 8. SAC outer loop (the paper's meta-optimizer), with explicit early-stopping flag
#
# This is the **actual SAC** used in the main paper: a tanh-squashed Gaussian actor, twin critics, target network, and Adam, taken directly from the original E3/E4/E7/E8 code and now driving the generic five-player inner loop through the same `outer_reward` scalar. Using the identical outer optimizer as the small-game experiments keeps the method consistent across scales.
#
# The `use_early_stopping` flag makes the behaviour standard and explicit: when `False` (our reported setting, matching the original notebooks' `patience=1000`) the full outer budget always runs; when `True`, search halts after `patience` non-improving steps. This directly resolves **Reviewer 3 major #4**.

# %%
def _kaiming(key,fan_in,fan_out):
    return jax.random.normal(key,(fan_in,fan_out))*jnp.sqrt(2.0/fan_in)
def init_actor_params(key, ctx_dim, n_params, hidden=256):
    k1,k2,k3,k4=jax.random.split(key,4)
    return {'w1':_kaiming(k1,ctx_dim,hidden),'b1':jnp.zeros(hidden),
            'w2':_kaiming(k2,hidden,hidden),'b2':jnp.zeros(hidden),
            'wm':_kaiming(k3,hidden,n_params),'bm':jnp.zeros(n_params),
            'ws':_kaiming(k4,hidden,n_params),'bs':jnp.zeros(n_params)}
def init_critic_params(key, ctx_dim, n_params, hidden=256):
    inp=ctx_dim+n_params; ks=jax.random.split(key,6)
    return {'w1_q1':_kaiming(ks[0],inp,hidden),'b1_q1':jnp.zeros(hidden),
            'w2_q1':_kaiming(ks[1],hidden,hidden),'b2_q1':jnp.zeros(hidden),
            'w3_q1':_kaiming(ks[2],hidden,1),'b3_q1':jnp.zeros(1),
            'w1_q2':_kaiming(ks[3],inp,hidden),'b1_q2':jnp.zeros(hidden),
            'w2_q2':_kaiming(ks[4],hidden,hidden),'b2_q2':jnp.zeros(hidden),
            'w3_q2':_kaiming(ks[5],hidden,1),'b3_q2':jnp.zeros(1)}
def actor_forward(p,s):
    h=jax.nn.relu(s@p['w1']+p['b1']); h=jax.nn.relu(h@p['w2']+p['b2'])
    return h@p['wm']+p['bm'], jnp.clip(h@p['ws']+p['bs'],-20,2)
def actor_sample(p,s,key):
    mean,log_std=actor_forward(p,s); std=jnp.exp(log_std)
    eps=jax.random.normal(key,mean.shape); a=jnp.tanh(mean+std*eps)
    lp=(-0.5*(eps**2+jnp.log(2*jnp.pi)+2*log_std)).sum(-1,keepdims=True)
    lp-=jnp.sum(jnp.log(1-a**2+1e-6),-1,keepdims=True)
    return a,lp
def q_value(cp,ctx,a):
    sa=jnp.concatenate([ctx,a])
    h=jax.nn.relu(sa@cp['w1_q1']+cp['b1_q1']); h=jax.nn.relu(h@cp['w2_q1']+cp['b2_q1']); q1=(h@cp['w3_q1']+cp['b3_q1'])[0]
    h2=jax.nn.relu(sa@cp['w1_q2']+cp['b1_q2']); h2=jax.nn.relu(h2@cp['w2_q2']+cp['b2_q2']); q2=(h2@cp['w3_q2']+cp['b3_q2'])[0]
    return q1,q2
def init_adam(params): return {'m':jax.tree_util.tree_map(jnp.zeros_like,params),
                               'v':jax.tree_util.tree_map(jnp.zeros_like,params),'t':0}
def adam_step(params,grads,state,lr=3e-4):
    t=state['t']+1
    m=jax.tree_util.tree_map(lambda m,g:0.9*m+0.1*g,state['m'],grads)
    v=jax.tree_util.tree_map(lambda v,g:0.999*v+0.001*g*g,state['v'],grads)
    mh=jax.tree_util.tree_map(lambda m:m/(1-0.9**t),m); vh=jax.tree_util.tree_map(lambda v:v/(1-0.999**t),v)
    new=jax.tree_util.tree_map(lambda p,a,b:p-lr*a/(jnp.sqrt(b)+1e-8),params,mh,vh)
    return new,{'m':m,'v':v,'t':t}

def sac_search(target_probs, n_runs, n_steps, n_episodes, use_early_stopping=False,
               patience=1000, alpha_ent=0.2, seed0=0, verbose_every=10):
    ctx=CTX; results=[]
    for run in range(n_runs):
        key=jax.random.PRNGKey(seed0+run*777); key,ka,kc=jax.random.split(key,3)
        ap=init_actor_params(ka,CTX_DIM,N_PARAMS); cp=init_critic_params(kc,CTX_DIM,N_PARAMS)
        co=init_adam(cp); ao=init_adam(ap)
        best_r=-1e18; best_theta=None; best_profile=None; stall=0
        for step in range(n_steps):
            key,ks,ke=jax.random.split(key,3)
            a,_=actor_sample(ap,ctx,ks)
            theta=scale_action_to_theta(np.clip((np.array(a)+1)/2,0,1))
            r,prof=outer_reward(theta,target_probs,ke,n_episodes)
            def closs(cp):
                q1,q2=q_value(cp,ctx,a); return (q1-r)**2+(q2-r)**2
            cp,co=adam_step(cp,jax.grad(closs)(cp),co)
            def aloss(ap):
                aa,lp=actor_sample(ap,ctx,ks); q1,_=q_value(cp,ctx,aa)
                return alpha_ent*lp.sum()-q1
            ap,ao=adam_step(ap,jax.grad(aloss)(ap),ao)
            if r>best_r: best_r=r; best_theta=theta; best_profile=prof; stall=0
            else: stall+=1
            if use_early_stopping and stall>=patience: break
        results.append(dict(run_id=run+1,reward=best_r,optimizer='SAC',profile=best_profile,**best_theta))
        if (run+1)%verbose_every==0: print(f"  SAC run {run+1}/{n_runs}: best_r={best_r:.3f}")
    return pd.DataFrame(results)
print("SAC outer loop defined (actor/twin-critic/adam, early stopping OFF by default)")
# Out:
# SAC outer loop defined (actor/twin-critic/adam, early stopping OFF by default)

# %% [markdown]
# ## 9. Validation without symbolic algebra: replicator simulation + numerical Jacobian
#
# Because no closed-form Jacobian exists for this game, we validate with the two tools that **survive into high dimensions** (Reviewer 1.2):
#
# 1. **Forward replicator simulation** from many random initial mixed profiles, integrating the multi-population replicator dynamics built directly from the payoff tensor; we check convergence to the target profile.
# 2. **Numerical Jacobian** at the recovered fixed point (finite differences of the replicator field) and its eigenvalues; all real parts negative $\Rightarrow$ asymptotically stable.
#
# Neither requires hand algebra, so both scale.

# %%
def replicator_field(state, payoff_tensor_np):
    # state: list of length N of prob vectors (len K_MAX, padded). Multi-population replicator.
    # Expected payoff to player i for each pure strategy s_i is obtained by contracting
    # payoff_tensor_np[i] over every OTHER player's mixed strategy. We contract axes from
    # highest to lowest index (skipping i) so the remaining axis indices stay valid.
    dstate=[]
    for i in range(N_PLAYERS):
        ev = payoff_tensor_np[i]                       # shape (k,)*N
        for j in reversed(range(N_PLAYERS)):
            if j==i: continue
            ev = np.tensordot(ev, state[j], axes=([j],[0]))
        ki=STRAT_COUNTS[i]
        ev=ev[:ki]; xi=state[i][:ki]
        avg=np.dot(xi,ev)
        d=xi*(ev-avg)
        full=np.zeros(K_MAX); full[:ki]=d
        dstate.append(full)
    return dstate

def simulate_replicator(theta_dict, target, n_starts=20, T=80.0, dt=0.1):
    pt=np.array(build_payoff_tensor(theta_dict))
    tgt=[np.array(target[i]) for i in range(N_PLAYERS)]
    successes=0
    for s in range(n_starts):
        rng=np.random.default_rng(1000+s)
        state=[_rand_simplex(rng,STRAT_COUNTS[i]) for i in range(N_PLAYERS)]
        for _ in range(int(T/dt)):
            d=replicator_field(state, pt)
            state=[_project(state[i]+dt*d[i], STRAT_COUNTS[i]) for i in range(N_PLAYERS)]
        # success if each player's argmax matches target argmax
        ok=all(np.argmax(state[i][:STRAT_COUNTS[i]])==np.argmax(tgt[i][:STRAT_COUNTS[i]])
               for i in range(N_PLAYERS))
        successes+=ok
    return successes/n_starts

def _rand_simplex(rng,k):
    v=rng.uniform(0,1,k); full=np.zeros(K_MAX); full[:k]=v/v.sum(); return full
def _project(v,k):
    v=np.clip(v,1e-6,None); s=v[:k].sum(); full=np.zeros(K_MAX); full[:k]=v[:k]/s; return full

print("validation (replicator + numerical Jacobian) defined")
# Out:
# validation (replicator + numerical Jacobian) defined

# %% [markdown]
# ## 10. Numerical Jacobian and eigenvalue check at the recovered profile
#
# We build the replicator vector field over the reduced coordinates (drop one share per player, since each simplex sums to one), evaluate its Jacobian by central finite differences at the target vertex, and report the eigenvalues. This is the scalable stand-in for the symbolic Jacobian of the small game.

# %%
def numerical_jacobian_eigs(theta_dict, target, eps=1e-4):
    pt=np.array(build_payoff_tensor(theta_dict))
    # reduced coordinates: for each player use first (k_i - 1) shares
    dims=[STRAT_COUNTS[i]-1 for i in range(N_PLAYERS)]
    def to_state(zred):
        state=[]; off=0
        for i in range(N_PLAYERS):
            ki=STRAT_COUNTS[i]; parts=zred[off:off+ki-1]; off+=ki-1
            full=np.zeros(K_MAX); full[:ki-1]=parts; full[ki-1]=1-parts.sum()
            state.append(np.clip(full,1e-6,1))
        return state
    def field_red(zred):
        st=to_state(zred); d=replicator_field(st,pt); out=[]
        for i in range(N_PLAYERS):
            out.extend(d[i][:STRAT_COUNTS[i]-1])
        return np.array(out)
    # target vertex in reduced coords
    z0=[]
    for i in range(N_PLAYERS):
        ki=STRAT_COUNTS[i]; a=np.argmax(target[i][:ki])
        vec=np.zeros(ki-1)
        if a<ki-1: vec[a]=1.0
        z0.extend(vec)
    z0=np.array(z0,dtype=float)
    n=len(z0); J=np.zeros((n,n))
    f0=field_red(z0)
    for j in range(n):
        zp=z0.copy(); zp[j]+=eps; zm=z0.copy(); zm[j]-=eps
        J[:,j]=(field_red(zp)-field_red(zm))/(2*eps)
    eigs=np.linalg.eigvals(J)
    return eigs, bool(np.all(eigs.real<1e-6))
print("numerical Jacobian defined")
# Out:
# numerical Jacobian defined

# %% [markdown]
# ## 11. Payoff-model switch (Option A vs Option C) and validation settings
#
# The setup above already loads the **wider, economically-ordered parameter bounds** (Option A: bigger ranges, with logical ordering `P > Cs_h`, cost tiers monotone, enforced by repair in `scale_action_to_theta`).
#
# **Option C** additionally uses the improved payoff model with three incentive levers — quality premium `Vq`, governance revenue `G`, inspection-service revenue `Sc` — that make quality and monitoring individually rational. Without them, good-governance profiles cannot be an ESS at *any* parameters (verified by a wide random scan). The cell above already defines `build_payoff_tensor` with these terms and the bounds include `Vq, G, Sc`, so this notebook runs **Option C** by default.
#
# If you want **pure Option A** (original payoff, no new incentives), set `USE_OPTION_C = False` below; the three incentive terms are then forced to zero so the payoff reduces to the original model (the scan will then show which profiles are ESS under the original economics).
#
# Validation uses **more replicator starts** for the scan: `N_VAL_SCAN = N_VAL_STARTS + 10`.

# %%
USE_OPTION_C = True   # True: improved payoff (Vq,G,Sc active). False: original payoff (they are zeroed).

# validation starts: +10 more than the configured default, for the 576-profile scan
N_VAL_SCAN = CFG['N_VAL_STARTS'] + 10
print("USE_OPTION_C =", USE_OPTION_C, "| N_VAL_SCAN =", N_VAL_SCAN)

# Capture the ORIGINAL payoff builder exactly once, so re-running this cell (e.g. to
# flip USE_OPTION_C) can never wrap an already-wrapped function -> no infinite recursion.
if '_orig_build_payoff' not in globals():
    _orig_build_payoff = build_payoff_tensor

def build_payoff_tensor(th):
    if not USE_OPTION_C:
        th = dict(th)
        th['Vq'] = 0.0
        th['G']  = 0.0
        th['Sc'] = 0.0
    return _orig_build_payoff(th)

print("payoff model ready:", "Option C (incentives ON)" if USE_OPTION_C else "Option A (incentives OFF)")
# Out:
# USE_OPTION_C = True | N_VAL_SCAN = 15
# payoff model ready: Option C (incentives ON)

# %% [markdown]
# ## 12. Enumerate all 576 pure-strategy profiles
#
# The joint pure-strategy space is `3 x 4 x 3 x 4 x 4 = 576`. We list every profile as a target.

# %%
import itertools

def onehot_target(choices):
    t=np.zeros((N_PLAYERS,K_MAX))
    for i,c in enumerate(choices):
        t[i, STRAT[PLAYERS[i]].index(c)]=1.0
    return jnp.array(t)

ALL_PROFILES = list(itertools.product(*[STRAT[p] for p in PLAYERS]))
print("total pure profiles:", len(ALL_PROFILES))
print("example:", ALL_PROFILES[0])
# Out:
# total pure profiles: 576
# example: ('high', 'fullQC', 'strict', 'accept', 'auditH')

# %% [markdown]
# ## 13. Scan all 576 profiles: one search each, then validate (ESS test)
#
# For every profile we run a **single** search (screening budget), then validate the recovered
# parameters with `N_VAL_SCAN` replicator simulations plus the numerical-Jacobian eigenvalue test.
#
# A profile is flagged **ESS** when the recovered parameters make it stable:
# `all_eig_neg == True` **and** all validation replicator starts converge (`repl_conv == 1.0`).
#
# The scan uses the **same paper-scale search budget per profile** as the final runs (`SCAN_STEPS = CFG['N_OUTER']`, `SCAN_EPISODES = CFG['N_EPISODES']`), so a profile is judged ESS under exactly the search power used later. One search run per profile can only *find* a stabilizing point if one exists; profiles with no ESS will fail here, which is what we want to detect. **Cost warning:** 576 profiles at full paper-scale search is a large job (many hours on GPU); the partial CSV is saved every 25 profiles so you can monitor and resume.
# Set `SCAN_METHOD` to `'SAC'` or `'BO'`. Progress and partial results are saved to CSV so the scan
# can be resumed / inspected.

# %%
SCAN_METHOD   = 'SAC'              # 'SAC' or 'BO'
# Scan at PAPER SCALE: same search budget per profile as the final runs.
SCAN_STEPS    = CFG['N_OUTER']    # = 200 at paper scale
SCAN_EPISODES = CFG['N_EPISODES'] # = 3000 at paper scale
os.makedirs(OUTDIR, exist_ok=True)
print(f"scan budget (paper-scale): steps={SCAN_STEPS}, episodes={SCAN_EPISODES} per profile")
print(f"NOTE: 576 profiles x this budget is a large job; run on GPU.")

def screen_one(choices, seed=0):
    target = onehot_target(choices)
    if SCAN_METHOD=='SAC':
        df = sac_search(target, n_runs=1, n_steps=SCAN_STEPS, n_episodes=SCAN_EPISODES,
                        use_early_stopping=False, patience=CFG['PATIENCE'], seed0=seed, verbose_every=10**9)
    else:
        df = bo_search(target, n_runs=1, n_calls=min(SCAN_STEPS,60), n_episodes=SCAN_EPISODES, seed0=seed)
    r = df.iloc[0]; th={n:float(r[n]) for n in PARAM_NAMES}
    conv = simulate_replicator(th, np.array(target), n_starts=N_VAL_SCAN)
    eigs, allneg = numerical_jacobian_eigs(th, np.array(target))
    is_ess = bool(allneg and conv>=1.0)
    row = dict(**{f'p{i}':choices[i] for i in range(N_PLAYERS)},
               reward=float(r['reward']), repl_conv=conv, all_eig_neg=bool(allneg),
               max_re_eig=float(np.max(eigs.real)), is_ess=is_ess,
               **{n:th[n] for n in PARAM_NAMES})
    return row

scan_rows=[]
t0=time.time()
for k,choices in enumerate(ALL_PROFILES):
    row = screen_one(choices, seed=k)
    scan_rows.append(row)
    
    # ---------- NEW: print immediately if this profile is ESS ----------
    if row['is_ess']:
        profile_label = ' / '.join(choices)
        print(f"✓ ESS found at profile #{k+1:3d}: {profile_label:50s}  "
              f"max_Re(eig)={row['max_re_eig']:+.3f}  repl_conv={row['repl_conv']:.2f}")
    # -------------------------------------------------------------------
    
    if (k+1)%1==0 or k==0:
        n_ess=sum(r['is_ess'] for r in scan_rows)
        print(f"  scanned {k+1}/{len(ALL_PROFILES)}  ESS-so-far={n_ess}  ({time.time()-t0:.0f}s)")
        pd.DataFrame(scan_rows).to_csv(os.path.join(OUTDIR,f'scan_ALL_{SCAN_METHOD}_partial.csv'), index=False)

scan_df = pd.DataFrame(scan_rows)
scan_df.to_csv(os.path.join(OUTDIR, f'scan_ALL_{SCAN_METHOD}.csv'), index=False)
print(f"\nSCAN DONE: {len(scan_df)} profiles, {int(scan_df['is_ess'].sum())} flagged ESS  ({time.time()-t0:.0f}s)")
# Out:
# scan budget (paper-scale): steps=200, episodes=3000 per profile
# NOTE: 576 profiles x this budget is a large job; run on GPU.
# ✓ ESS found at profile #  1: high / fullQC / strict / accept / auditH            max_Re(eig)=-10.113  repl_conv=1.00
#   scanned 1/576  ESS-so-far=1  (33s)
# ✓ ESS found at profile #  2: high / fullQC / strict / accept / auditM            max_Re(eig)=-4.972  repl_conv=1.00
#   scanned 2/576  ESS-so-far=2  (67s)
# ✓ ESS found at profile #  3: high / fullQC / strict / accept / auditL            max_Re(eig)=-1.818  repl_conv=1.00
#   scanned 3/576  ESS-so-far=3  (100s)
# ✓ ESS found at profile #  4: high / fullQC / strict / accept / noAudit           max_Re(eig)=-1.882  repl_conv=1.00
#   scanned 4/576  ESS-so-far=4  (133s)
#   scanned 5/576  ESS-so-far=4  (167s)
#   scanned 6/576  ESS-so-far=4  (201s)
#   scanned 7/576  ESS-so-far=4  (234s)
#   scanned 8/576  ESS-so-far=4  (265s)
#   scanned 9/576  ESS-so-far=4  (296s)
#   scanned 10/576  ESS-so-far=4  (327s)
#   scanned 11/576  ESS-so-far=4  (358s)
#   scanned 12/576  ESS-so-far=4  (389s)
#   scanned 13/576  ESS-so-far=4  (419s)
#   scanned 14/576  ESS-so-far=4  (451s)
#   scanned 15/576  ESS-so-far=4  (483s)
#   scanned 16/576  ESS-so-far=4  (515s)
# ✓ ESS found at profile # 17: high / fullQC / sampling / accept / auditH          max_Re(eig)=-0.644  repl_conv=1.00
#   scanned 17/576  ESS-so-far=5  (546s)
# ✓ ESS found at profile # 18: high / fullQC / sampling / accept / auditM          max_Re(eig)=-2.458  repl_conv=1.00
#   scanned 18/576  ESS-so-far=6  (577s)
#   scanned 19/576  ESS-so-far=6  (608s)
# ✓ ESS found at profile # 20: high / fullQC / sampling / accept / noAudit         max_Re(eig)=-0.616  repl_conv=1.00
#   scanned 20/576  ESS-so-far=7  (640s)
#   scanned 21/576  ESS-so-far=7  (669s)
#   scanned 22/576  ESS-so-far=7  (698s)
#   scanned 23/576  ESS-so-far=7  (727s)
#   scanned 24/576  ESS-so-far=7  (756s)
#   scanned 25/576  ESS-so-far=7  (786s)
#   scanned 26/576  ESS-so-far=7  (814s)
#   scanned 27/576  ESS-so-far=7  (843s)
#   scanned 28/576  ESS-so-far=7  (872s)
#   scanned 29/576  ESS-so-far=7  (901s)
#   scanned 30/576  ESS-so-far=7  (931s)
#   scanned 31/576  ESS-so-far=7  (964s)
#   scanned 32/576  ESS-so-far=7  (993s)
# ✓ ESS found at profile # 33: high / fullQC / slack / accept / auditH             max_Re(eig)=-2.905  repl_conv=1.00
#   scanned 33/576  ESS-so-far=8  (1023s)
#   scanned 34/576  ESS-so-far=8  (1053s)
#   scanned 35/576  ESS-so-far=8  (1083s)
#   scanned 36/576  ESS-so-far=8  (1112s)
#   scanned 37/576  ESS-so-far=8  (1142s)
#   scanned 38/576  ESS-so-far=8  (1171s)
#   scanned 39/576  ESS-so-far=8  (1200s)
#   scanned 40/576  ESS-so-far=8  (1229s)
#   scanned 41/576  ESS-so-far=8  (1258s)
#   scanned 42/576  ESS-so-far=8  (1288s)
#   scanned 43/576  ESS-so-far=8  (1318s)
#   scanned 44/576  ESS-so-far=8  (1348s)
#   scanned 45/576  ESS-so-far=8  (1378s)
#   scanned 46/576  ESS-so-far=8  (1408s)
#   scanned 47/576  ESS-so-far=8  (1438s)
#   scanned 48/576  ESS-so-far=8  (1467s)
# ✓ ESS found at profile # 49: high / partQC / strict / accept / auditH            max_Re(eig)=-4.696  repl_conv=1.00
#   scanned 49/576  ESS-so-far=9  (1497s)
#   scanned 50/576  ESS-so-far=9  (1527s)
#   scanned 51/576  ESS-so-far=9  (1556s)
#   scanned 52/576  ESS-so-far=9  (1585s)
#   scanned 53/576  ESS-so-far=9  (1614s)
#   scanned 54/576  ESS-so-far=9  (1643s)
#   scanned 55/576  ESS-so-far=9  (1672s)
#   scanned 56/576  ESS-so-far=9  (1701s)
#   scanned 57/576  ESS-so-far=9  (1730s)
#   scanned 58/576  ESS-so-far=9  (1759s)
#   scanned 59/576  ESS-so-far=9  (1788s)
#   scanned 60/576  ESS-so-far=9  (1817s)
#   scanned 61/576  ESS-so-far=9  (1846s)
#   scanned 62/576  ESS-so-far=9  (1875s)
#   scanned 63/576  ESS-so-far=9  (1904s)
#   scanned 64/576  ESS-so-far=9  (1933s)
# ✓ ESS found at profile # 65: high / partQC / sampling / accept / auditH          max_Re(eig)=-1.417  repl_conv=1.00
#   scanned 65/576  ESS-so-far=10  (1962s)
# ✓ ESS found at profile # 66: high / partQC / sampling / accept / auditM          max_Re(eig)=-0.333  repl_conv=1.00
#   scanned 66/576  ESS-so-far=11  (1991s)
#   scanned 67/576  ESS-so-far=11  (2020s)
# ✓ ESS found at profile # 68: high / partQC / sampling / accept / noAudit         max_Re(eig)=-1.015  repl_conv=1.00
#   scanned 68/576  ESS-so-far=12  (2049s)
#   scanned 69/576  ESS-so-far=12  (2078s)
#   scanned 70/576  ESS-so-far=12  (2107s)
#   scanned 71/576  ESS-so-far=12  (2136s)
#   scanned 72/576  ESS-so-far=12  (2165s)
#   scanned 73/576  ESS-so-far=12  (2194s)
#   scanned 74/576  ESS-so-far=12  (2223s)
#   scanned 75/576  ESS-so-far=12  (2252s)
#   scanned 76/576  ESS-so-far=12  (2281s)
#   scanned 77/576  ESS-so-far=12  (2310s)
#   scanned 78/576  ESS-so-far=12  (2339s)
#   scanned 79/576  ESS-so-far=12  (2368s)
#   scanned 80/576  ESS-so-far=12  (2397s)
#   scanned 81/576  ESS-so-far=12  (2426s)
#   scanned 82/576  ESS-so-far=12  (2456s)
#   scanned 83/576  ESS-so-far=12  (2485s)
#   scanned 84/576  ESS-so-far=12  (2514s)
#   scanned 85/576  ESS-so-far=12  (2543s)
#   scanned 86/576  ESS-so-far=12  (2573s)
#   scanned 87/576  ESS-so-far=12  (2602s)
#   scanned 88/576  ESS-so-far=12  (2631s)
#   scanned 89/576  ESS-so-far=12  (2661s)
#   scanned 90/576  ESS-so-far=12  (2690s)
#   scanned 91/576  ESS-so-far=12  (2719s)
#   scanned 92/576  ESS-so-far=12  (2748s)
#   scanned 93/576  ESS-so-far=12  (2778s)
#   scanned 94/576  ESS-so-far=12  (2807s)
#   scanned 95/576  ESS-so-far=12  (2837s)
#   scanned 96/576  ESS-so-far=12  (2871s)
#   scanned 97/576  ESS-so-far=12  (2903s)
# ✓ ESS found at profile # 98: high / minQC / strict / accept / auditM             max_Re(eig)=-2.572  repl_conv=1.00
#   scanned 98/576  ESS-so-far=13  (2932s)
# ✓ ESS found at profile # 99: high / minQC / strict / accept / auditL             max_Re(eig)=-0.977  repl_conv=1.00
#   scanned 99/576  ESS-so-far=14  (2961s)
#   scanned 100/576  ESS-so-far=14  (2990s)
#   scanned 101/576  ESS-so-far=14  (3019s)
#   scanned 102/576  ESS-so-far=14  (3048s)
#   scanned 103/576  ESS-so-far=14  (3077s)
#   scanned 104/576  ESS-so-far=14  (3106s)
#   scanned 105/576  ESS-so-far=14  (3136s)
#   scanned 106/576  ESS-so-far=14  (3166s)
#   scanned 107/576  ESS-so-far=14  (3195s)
#   scanned 108/576  ESS-so-far=14  (3224s)
#   scanned 109/576  ESS-so-far=14  (3253s)
#   scanned 110/576  ESS-so-far=14  (3282s)
#   scanned 111/576  ESS-so-far=14  (3311s)
#   scanned 112/576  ESS-so-far=14  (3341s)
#   scanned 113/576  ESS-so-far=14  (3370s)
#   scanned 114/576  ESS-so-far=14  (3399s)
#   scanned 115/576  ESS-so-far=14  (3428s)
#   scanned 116/576  ESS-so-far=14  (3457s)
#   scanned 117/576  ESS-so-far=14  (3487s)
#   scanned 118/576  ESS-so-far=14  (3516s)
#   scanned 119/576  ESS-so-far=14  (3545s)
#   scanned 120/576  ESS-so-far=14  (3574s)
#   scanned 121/576  ESS-so-far=14  (3604s)
#   scanned 122/576  ESS-so-far=14  (3634s)
#   scanned 123/576  ESS-so-far=14  (3665s)
#   scanned 124/576  ESS-so-far=14  (3694s)
#   scanned 125/576  ESS-so-far=14  (3725s)
#   scanned 126/576  ESS-so-far=14  (3755s)
#   scanned 127/576  ESS-so-far=14  (3785s)
#   scanned 128/576  ESS-so-far=14  (3815s)
#   scanned 129/576  ESS-so-far=14  (3845s)
#   scanned 130/576  ESS-so-far=14  (3874s)
#   scanned 131/576  ESS-so-far=14  (3904s)
#   scanned 132/576  ESS-so-far=14  (3934s)
#   scanned 133/576  ESS-so-far=14  (3964s)
#   scanned 134/576  ESS-so-far=14  (3994s)
#   scanned 135/576  ESS-so-far=14  (4023s)
#   scanned 136/576  ESS-so-far=14  (4053s)
#   scanned 137/576  ESS-so-far=14  (4083s)
#   scanned 138/576  ESS-so-far=14  (4115s)
#   scanned 139/576  ESS-so-far=14  (4148s)
#   scanned 140/576  ESS-so-far=14  (4178s)
#   scanned 141/576  ESS-so-far=14  (4208s)
#   scanned 142/576  ESS-so-far=14  (4238s)
#   scanned 143/576  ESS-so-far=14  (4268s)
#   scanned 144/576  ESS-so-far=14  (4297s)
#   scanned 145/576  ESS-so-far=14  (4327s)
#   scanned 146/576  ESS-so-far=14  (4357s)
#   scanned 147/576  ESS-so-far=14  (4387s)
#   scanned 148/576  ESS-so-far=14  (4417s)
#   scanned 149/576  ESS-so-far=14  (4447s)
#   scanned 150/576  ESS-so-far=14  (4477s)
#   scanned 151/576  ESS-so-far=14  (4507s)
#   scanned 152/576  ESS-so-far=14  (4537s)
#   scanned 153/576  ESS-so-far=14  (4566s)
#   scanned 154/576  ESS-so-far=14  (4596s)
#   scanned 155/576  ESS-so-far=14  (4625s)
#   scanned 156/576  ESS-so-far=14  (4655s)
#   scanned 157/576  ESS-so-far=14  (4685s)
#   scanned 158/576  ESS-so-far=14  (4715s)
#   scanned 159/576  ESS-so-far=14  (4745s)
#   scanned 160/576  ESS-so-far=14  (4774s)
#   scanned 161/576  ESS-so-far=14  (5259s)
#   scanned 162/576  ESS-so-far=14  (5291s)
#   scanned 163/576  ESS-so-far=14  (5322s)
#   scanned 164/576  ESS-so-far=14  (5353s)
#   scanned 165/576  ESS-so-far=14  (5383s)
#   scanned 166/576  ESS-so-far=14  (5418s)
#   scanned 167/576  ESS-so-far=14  (5455s)
#   scanned 168/576  ESS-so-far=14  (5491s)
#   scanned 169/576  ESS-so-far=14  (5525s)
#   scanned 170/576  ESS-so-far=14  (5558s)
#   scanned 171/576  ESS-so-far=14  (5592s)
#   scanned 172/576  ESS-so-far=14  (5622s)
#   scanned 173/576  ESS-so-far=14  (5653s)
#   scanned 174/576  ESS-so-far=14  (5685s)
#   scanned 175/576  ESS-so-far=14  (5716s)
#   scanned 176/576  ESS-so-far=14  (5746s)
#   scanned 177/576  ESS-so-far=14  (5776s)
#   scanned 178/576  ESS-so-far=14  (5807s)
#   scanned 179/576  ESS-so-far=14  (5837s)
#   scanned 180/576  ESS-so-far=14  (5868s)
#   scanned 181/576  ESS-so-far=14  (5900s)
#   scanned 182/576  ESS-so-far=14  (5930s)
#   scanned 183/576  ESS-so-far=14  (5960s)
#   scanned 184/576  ESS-so-far=14  (5989s)
#   scanned 185/576  ESS-so-far=14  (6022s)
#   scanned 186/576  ESS-so-far=14  (6053s)
#   scanned 187/576  ESS-so-far=14  (6082s)
#   scanned 188/576  ESS-so-far=14  (6111s)
#   scanned 189/576  ESS-so-far=14  (6140s)
#   scanned 190/576  ESS-so-far=14  (6171s)
#   scanned 191/576  ESS-so-far=14  (6203s)
#   scanned 192/576  ESS-so-far=14  (6233s)
# ✓ ESS found at profile #193: standard / fullQC / strict / accept / auditH        max_Re(eig)=-1.845  repl_conv=1.00
#   scanned 193/576  ESS-so-far=15  (6262s)
# ✓ ESS found at profile #194: standard / fullQC / strict / accept / auditM        max_Re(eig)=-2.973  repl_conv=1.00
#   scanned 194/576  ESS-so-far=16  (6292s)
# ✓ ESS found at profile #195: standard / fullQC / strict / accept / auditL        max_Re(eig)=-4.800  repl_conv=1.00
#   scanned 195/576  ESS-so-far=17  (6324s)
# ✓ ESS found at profile #196: standard / fullQC / strict / accept / noAudit       max_Re(eig)=-1.004  repl_conv=1.00
#   scanned 196/576  ESS-so-far=18  (6355s)
#   scanned 197/576  ESS-so-far=18  (6386s)
#   scanned 198/576  ESS-so-far=18  (6416s)
#   scanned 199/576  ESS-so-far=18  (6445s)
#   scanned 200/576  ESS-so-far=18  (6474s)
#   scanned 201/576  ESS-so-far=18  (6506s)
#   scanned 202/576  ESS-so-far=18  (6540s)
#   scanned 203/576  ESS-so-far=18  (6573s)
#   scanned 204/576  ESS-so-far=18  (6606s)
#   scanned 205/576  ESS-so-far=18  (6637s)
#   scanned 206/576  ESS-so-far=18  (6668s)
#   scanned 207/576  ESS-so-far=18  (6699s)
#   scanned 208/576  ESS-so-far=18  (6731s)
# ✓ ESS found at profile #209: standard / fullQC / sampling / accept / auditH      max_Re(eig)=-6.594  repl_conv=1.00
#   scanned 209/576  ESS-so-far=19  (6762s)
# ✓ ESS found at profile #210: standard / fullQC / sampling / accept / auditM      max_Re(eig)=-0.523  repl_conv=1.00
#   scanned 210/576  ESS-so-far=20  (6793s)
# ✓ ESS found at profile #211: standard / fullQC / sampling / accept / auditL      max_Re(eig)=-2.896  repl_conv=1.00
#   scanned 211/576  ESS-so-far=21  (6824s)
# ✓ ESS found at profile #212: standard / fullQC / sampling / accept / noAudit     max_Re(eig)=-3.115  repl_conv=1.00
#   scanned 212/576  ESS-so-far=22  (6855s)
#   scanned 213/576  ESS-so-far=22  (6886s)
#   scanned 214/576  ESS-so-far=22  (6917s)
#   scanned 215/576  ESS-so-far=22  (6948s)
#   scanned 216/576  ESS-so-far=22  (6979s)
#   scanned 217/576  ESS-so-far=22  (7010s)
#   scanned 218/576  ESS-so-far=22  (7041s)
#   scanned 219/576  ESS-so-far=22  (7076s)
#   scanned 220/576  ESS-so-far=22  (7108s)
#   scanned 221/576  ESS-so-far=22  (7139s)
#   scanned 222/576  ESS-so-far=22  (7170s)
#   scanned 223/576  ESS-so-far=22  (7201s)
#   scanned 224/576  ESS-so-far=22  (7235s)
# ✓ ESS found at profile #225: standard / fullQC / slack / accept / auditH         max_Re(eig)=-5.004  repl_conv=1.00
#   scanned 225/576  ESS-so-far=23  (7270s)
#   scanned 226/576  ESS-so-far=23  (7303s)
#   scanned 227/576  ESS-so-far=23  (7337s)
#   scanned 228/576  ESS-so-far=23  (7370s)
#   scanned 229/576  ESS-so-far=23  (7403s)
#   scanned 230/576  ESS-so-far=23  (7434s)
#   scanned 231/576  ESS-so-far=23  (7464s)
#   scanned 232/576  ESS-so-far=23  (7493s)
#   scanned 233/576  ESS-so-far=23  (7521s)
# ✓ ESS found at profile #234: standard / fullQC / slack / return / auditM         max_Re(eig)=-0.922  repl_conv=1.00
#   scanned 234/576  ESS-so-far=24  (7550s)
#   scanned 235/576  ESS-so-far=24  (7580s)
#   scanned 236/576  ESS-so-far=24  (7609s)
#   scanned 237/576  ESS-so-far=24  (7638s)
#   scanned 238/576  ESS-so-far=24  (7669s)
#   scanned 239/576  ESS-so-far=24  (7698s)
#   scanned 240/576  ESS-so-far=24  (7727s)
#   scanned 241/576  ESS-so-far=24  (7756s)
# ✓ ESS found at profile #242: standard / partQC / strict / accept / auditM        max_Re(eig)=-1.285  repl_conv=1.00
#   scanned 242/576  ESS-so-far=25  (7786s)
# ✓ ESS found at profile #243: standard / partQC / strict / accept / auditL        max_Re(eig)=-3.576  repl_conv=1.00
#   scanned 243/576  ESS-so-far=26  (7815s)
# ✓ ESS found at profile #244: standard / partQC / strict / accept / noAudit       max_Re(eig)=-2.091  repl_conv=1.00
#   scanned 244/576  ESS-so-far=27  (7844s)
#   scanned 245/576  ESS-so-far=27  (7873s)
#   scanned 246/576  ESS-so-far=27  (7902s)
#   scanned 247/576  ESS-so-far=27  (7931s)
#   scanned 248/576  ESS-so-far=27  (7961s)
#   scanned 249/576  ESS-so-far=27  (7990s)
#   scanned 250/576  ESS-so-far=27  (8019s)
#   scanned 251/576  ESS-so-far=27  (8048s)
#   scanned 252/576  ESS-so-far=27  (8077s)
#   scanned 253/576  ESS-so-far=27  (8106s)
#   scanned 254/576  ESS-so-far=27  (8136s)
#   scanned 255/576  ESS-so-far=27  (8167s)
#   scanned 256/576  ESS-so-far=27  (8203s)
# ✓ ESS found at profile #257: standard / partQC / sampling / accept / auditH      max_Re(eig)=-4.252  repl_conv=1.00
#   scanned 257/576  ESS-so-far=28  (8232s)
#   scanned 258/576  ESS-so-far=28  (8261s)
# ✓ ESS found at profile #259: standard / partQC / sampling / accept / auditL      max_Re(eig)=-1.033  repl_conv=1.00
#   scanned 259/576  ESS-so-far=29  (8290s)
#   scanned 260/576  ESS-so-far=29  (8319s)
#   scanned 261/576  ESS-so-far=29  (8349s)
#   scanned 262/576  ESS-so-far=29  (8378s)
#   scanned 263/576  ESS-so-far=29  (8423s)
#   scanned 264/576  ESS-so-far=29  (8452s)
#   scanned 265/576  ESS-so-far=29  (8481s)
#   scanned 266/576  ESS-so-far=29  (8511s)
#   scanned 267/576  ESS-so-far=29  (8542s)
#   scanned 268/576  ESS-so-far=29  (8575s)
#   scanned 269/576  ESS-so-far=29  (8605s)
#   scanned 270/576  ESS-so-far=29  (8634s)
#   scanned 271/576  ESS-so-far=29  (8663s)
#   scanned 272/576  ESS-so-far=29  (8692s)
# ✓ ESS found at profile #273: standard / partQC / slack / accept / auditH         max_Re(eig)=-3.345  repl_conv=1.00
#   scanned 273/576  ESS-so-far=30  (8721s)
#   scanned 274/576  ESS-so-far=30  (8749s)
#   scanned 275/576  ESS-so-far=30  (8778s)
#   scanned 276/576  ESS-so-far=30  (8807s)
# ✓ ESS found at profile #277: standard / partQC / slack / reinspect / auditH      max_Re(eig)=-1.590  repl_conv=1.00
#   scanned 277/576  ESS-so-far=31  (8836s)
#   scanned 278/576  ESS-so-far=31  (8865s)
#   scanned 279/576  ESS-so-far=31  (8894s)
#   scanned 280/576  ESS-so-far=31  (8925s)
#   scanned 281/576  ESS-so-far=31  (8957s)
#   scanned 282/576  ESS-so-far=31  (8987s)
#   scanned 283/576  ESS-so-far=31  (9018s)
#   scanned 284/576  ESS-so-far=31  (9048s)
#   scanned 285/576  ESS-so-far=31  (9078s)
#   scanned 286/576  ESS-so-far=31  (9107s)
#   scanned 287/576  ESS-so-far=31  (9137s)
#   scanned 288/576  ESS-so-far=31  (9167s)
#   scanned 289/576  ESS-so-far=31  (9199s)
# ✓ ESS found at profile #290: standard / minQC / strict / accept / auditM         max_Re(eig)=-1.148  repl_conv=1.00
#   scanned 290/576  ESS-so-far=32  (9233s)
#   scanned 291/576  ESS-so-far=32  (9262s)
# ✓ ESS found at profile #292: standard / minQC / strict / accept / noAudit        max_Re(eig)=-2.057  repl_conv=1.00
#   scanned 292/576  ESS-so-far=33  (9291s)
#   scanned 293/576  ESS-so-far=33  (9320s)
#   scanned 294/576  ESS-so-far=33  (9350s)
#   scanned 295/576  ESS-so-far=33  (9380s)
#   scanned 296/576  ESS-so-far=33  (9409s)
#   scanned 297/576  ESS-so-far=33  (9439s)
#   scanned 298/576  ESS-so-far=33  (9470s)
#   scanned 299/576  ESS-so-far=33  (9501s)
#   scanned 300/576  ESS-so-far=33  (9531s)
#   scanned 301/576  ESS-so-far=33  (9561s)
#   scanned 302/576  ESS-so-far=33  (9591s)
#   scanned 303/576  ESS-so-far=33  (9622s)
#   scanned 304/576  ESS-so-far=33  (9653s)
#   scanned 305/576  ESS-so-far=33  (9684s)
#   scanned 306/576  ESS-so-far=33  (9716s)
#   scanned 307/576  ESS-so-far=33  (9749s)
#   scanned 308/576  ESS-so-far=33  (9781s)
#   scanned 309/576  ESS-so-far=33  (9813s)
#   scanned 310/576  ESS-so-far=33  (9845s)
#   scanned 311/576  ESS-so-far=33  (9878s)
#   scanned 312/576  ESS-so-far=33  (9910s)
#   scanned 313/576  ESS-so-far=33  (9950s)
#   scanned 314/576  ESS-so-far=33  (9982s)
#   scanned 315/576  ESS-so-far=33  (10014s)
#   scanned 316/576  ESS-so-far=33  (10048s)
#   scanned 317/576  ESS-so-far=33  (10081s)
#   scanned 318/576  ESS-so-far=33  (10114s)
#   scanned 319/576  ESS-so-far=33  (10147s)
#   scanned 320/576  ESS-so-far=33  (10178s)
#   scanned 321/576  ESS-so-far=33  (10208s)
#   scanned 322/576  ESS-so-far=33  (10237s)
#   scanned 323/576  ESS-so-far=33  (10266s)
#   scanned 324/576  ESS-so-far=33  (10297s)
#   scanned 325/576  ESS-so-far=33  (10330s)
#   scanned 326/576  ESS-so-far=33  (10364s)
#   scanned 327/576  ESS-so-far=33  (10395s)
#   scanned 328/576  ESS-so-far=33  (10427s)
#   scanned 329/576  ESS-so-far=33  (10460s)
#   scanned 330/576  ESS-so-far=33  (10491s)
#   scanned 331/576  ESS-so-far=33  (10522s)
#   scanned 332/576  ESS-so-far=33  (10551s)
#   scanned 333/576  ESS-so-far=33  (10581s)
#   scanned 334/576  ESS-so-far=33  (10610s)
#   scanned 335/576  ESS-so-far=33  (10640s)
#   scanned 336/576  ESS-so-far=33  (10674s)
#   scanned 337/576  ESS-so-far=33  (10707s)
#   scanned 338/576  ESS-so-far=33  (10739s)
#   scanned 339/576  ESS-so-far=33  (10770s)
#   scanned 340/576  ESS-so-far=33  (10801s)
#   scanned 341/576  ESS-so-far=33  (10833s)
#   scanned 342/576  ESS-so-far=33  (10865s)
#   scanned 343/576  ESS-so-far=33  (10897s)
#   scanned 344/576  ESS-so-far=33  (10929s)
#   scanned 345/576  ESS-so-far=33  (10960s)
#   scanned 346/576  ESS-so-far=33  (10991s)
#   scanned 347/576  ESS-so-far=33  (11022s)
#   scanned 348/576  ESS-so-far=33  (11055s)
#   scanned 349/576  ESS-so-far=33  (11085s)
#   scanned 350/576  ESS-so-far=33  (11116s)
#   scanned 351/576  ESS-so-far=33  (11147s)
#   scanned 352/576  ESS-so-far=33  (11176s)
#   scanned 353/576  ESS-so-far=33  (11205s)
#   scanned 354/576  ESS-so-far=33  (11234s)
#   scanned 355/576  ESS-so-far=33  (11263s)
#   scanned 356/576  ESS-so-far=33  (11292s)
#   scanned 357/576  ESS-so-far=33  (11321s)
#   scanned 358/576  ESS-so-far=33  (11350s)
#   scanned 359/576  ESS-so-far=33  (11379s)
#   scanned 360/576  ESS-so-far=33  (11408s)
#   scanned 361/576  ESS-so-far=33  (11437s)
#   scanned 362/576  ESS-so-far=33  (11466s)
#   scanned 363/576  ESS-so-far=33  (11495s)
#   scanned 364/576  ESS-so-far=33  (11524s)
#   scanned 365/576  ESS-so-far=33  (11555s)
#   scanned 366/576  ESS-so-far=33  (11586s)
#   scanned 367/576  ESS-so-far=33  (11616s)
#   scanned 368/576  ESS-so-far=33  (11645s)
#   scanned 369/576  ESS-so-far=33  (11674s)
#   scanned 370/576  ESS-so-far=33  (11704s)
#   scanned 371/576  ESS-so-far=33  (11735s)
#   scanned 372/576  ESS-so-far=33  (11768s)
#   scanned 373/576  ESS-so-far=33  (11807s)
#   scanned 374/576  ESS-so-far=33  (11837s)
#   scanned 375/576  ESS-so-far=33  (11866s)
#   scanned 376/576  ESS-so-far=33  (11896s)
#   scanned 377/576  ESS-so-far=33  (11925s)
#   scanned 378/576  ESS-so-far=33  (11954s)
#   scanned 379/576  ESS-so-far=33  (11983s)
#   scanned 380/576  ESS-so-far=33  (12012s)
#   scanned 381/576  ESS-so-far=33  (12041s)
#   scanned 382/576  ESS-so-far=33  (12071s)
#   scanned 383/576  ESS-so-far=33  (12100s)
#   scanned 384/576  ESS-so-far=33  (12129s)
#   scanned 385/576  ESS-so-far=33  (12158s)
#   scanned 386/576  ESS-so-far=33  (12187s)
#   scanned 387/576  ESS-so-far=33  (12216s)
#   scanned 388/576  ESS-so-far=33  (12245s)
#   scanned 389/576  ESS-so-far=33  (12274s)
#   scanned 390/576  ESS-so-far=33  (12303s)
#   scanned 391/576  ESS-so-far=33  (12332s)
#   scanned 392/576  ESS-so-far=33  (12361s)
# ✓ ESS found at profile #393: sub / fullQC / strict / return / auditH             max_Re(eig)=-0.603  repl_conv=1.00
#   scanned 393/576  ESS-so-far=34  (12390s)
#   scanned 394/576  ESS-so-far=34  (12419s)
#   scanned 395/576  ESS-so-far=34  (12448s)
#   scanned 396/576  ESS-so-far=34  (12478s)
#   scanned 397/576  ESS-so-far=34  (12507s)
#   scanned 398/576  ESS-so-far=34  (12537s)
#   scanned 399/576  ESS-so-far=34  (12567s)
#   scanned 400/576  ESS-so-far=34  (12598s)
# ✓ ESS found at profile #401: sub / fullQC / sampling / accept / auditH           max_Re(eig)=-7.500  repl_conv=1.00
#   scanned 401/576  ESS-so-far=35  (12633s)
#   scanned 402/576  ESS-so-far=35  (12665s)
#   scanned 403/576  ESS-so-far=35  (12697s)
#   scanned 404/576  ESS-so-far=35  (12729s)
#   scanned 405/576  ESS-so-far=35  (12761s)
#   scanned 406/576  ESS-so-far=35  (12792s)
#   scanned 407/576  ESS-so-far=35  (12823s)
#   scanned 408/576  ESS-so-far=35  (12854s)
#   scanned 409/576  ESS-so-far=35  (12884s)
#   scanned 410/576  ESS-so-far=35  (12913s)
#   scanned 411/576  ESS-so-far=35  (12943s)
# ✓ ESS found at profile #412: sub / fullQC / sampling / return / noAudit          max_Re(eig)=-0.087  repl_conv=1.00
#   scanned 412/576  ESS-so-far=36  (12972s)
#   scanned 413/576  ESS-so-far=36  (13002s)
#   scanned 414/576  ESS-so-far=36  (13032s)
#   scanned 415/576  ESS-so-far=36  (13065s)
#   scanned 416/576  ESS-so-far=36  (13098s)
#   scanned 417/576  ESS-so-far=36  (13129s)
#   scanned 418/576  ESS-so-far=36  (13159s)
#   scanned 419/576  ESS-so-far=36  (13189s)
#   scanned 420/576  ESS-so-far=36  (13218s)
#   scanned 421/576  ESS-so-far=36  (13251s)
#   scanned 422/576  ESS-so-far=36  (13285s)
#   scanned 423/576  ESS-so-far=36  (13317s)
#   scanned 424/576  ESS-so-far=36  (13350s)
#   scanned 425/576  ESS-so-far=36  (13384s)
#   scanned 426/576  ESS-so-far=36  (13418s)
#   scanned 427/576  ESS-so-far=36  (13453s)
#   scanned 428/576  ESS-so-far=36  (13487s)
#   scanned 429/576  ESS-so-far=36  (13522s)
#   scanned 430/576  ESS-so-far=36  (13559s)
#   scanned 431/576  ESS-so-far=36  (13592s)
#   scanned 432/576  ESS-so-far=36  (13626s)
#   scanned 433/576  ESS-so-far=36  (13657s)
# ✓ ESS found at profile #434: sub / partQC / strict / accept / auditM             max_Re(eig)=-2.151  repl_conv=1.00
#   scanned 434/576  ESS-so-far=37  (13692s)
#   scanned 435/576  ESS-so-far=37  (13727s)
#   scanned 436/576  ESS-so-far=37  (13759s)
#   scanned 437/576  ESS-so-far=37  (13793s)
#   scanned 438/576  ESS-so-far=37  (13827s)
#   scanned 439/576  ESS-so-far=37  (13860s)
#   scanned 440/576  ESS-so-far=37  (13891s)
#   scanned 441/576  ESS-so-far=37  (13923s)
#   scanned 442/576  ESS-so-far=37  (13966s)
# ✓ ESS found at profile #443: sub / partQC / strict / return / auditL             max_Re(eig)=-1.226  repl_conv=1.00
#   scanned 443/576  ESS-so-far=38  (13997s)
#   scanned 444/576  ESS-so-far=38  (14027s)
#   scanned 445/576  ESS-so-far=38  (14067s)
#   scanned 446/576  ESS-so-far=38  (14104s)
#   scanned 447/576  ESS-so-far=38  (14141s)
#   scanned 448/576  ESS-so-far=38  (14175s)
#   scanned 449/576  ESS-so-far=38  (14211s)
#   scanned 450/576  ESS-so-far=38  (14248s)
#   scanned 451/576  ESS-so-far=38  (14284s)
#   scanned 452/576  ESS-so-far=38  (14319s)
#   scanned 453/576  ESS-so-far=38  (14352s)
#   scanned 454/576  ESS-so-far=38  (14383s)
#   scanned 455/576  ESS-so-far=38  (14413s)
#   scanned 456/576  ESS-so-far=38  (14446s)
#   scanned 457/576  ESS-so-far=38  (14476s)
#   scanned 458/576  ESS-so-far=38  (14510s)
#   scanned 459/576  ESS-so-far=38  (14560s)
#   scanned 460/576  ESS-so-far=38  (14592s)
#   scanned 461/576  ESS-so-far=38  (14623s)
#   scanned 462/576  ESS-so-far=38  (14661s)
#   scanned 463/576  ESS-so-far=38  (14697s)
#   scanned 464/576  ESS-so-far=38  (14731s)
#   scanned 465/576  ESS-so-far=38  (14766s)
#   scanned 466/576  ESS-so-far=38  (14800s)
#   scanned 467/576  ESS-so-far=38  (14836s)
#   scanned 468/576  ESS-so-far=38  (14869s)
#   scanned 469/576  ESS-so-far=38  (14903s)
#   scanned 470/576  ESS-so-far=38  (14938s)
#   scanned 471/576  ESS-so-far=38  (14971s)
#   scanned 472/576  ESS-so-far=38  (15003s)
# ✓ ESS found at profile #473: sub / partQC / slack / return / auditH              max_Re(eig)=-1.616  repl_conv=1.00
#   scanned 473/576  ESS-so-far=39  (15036s)
#   scanned 474/576  ESS-so-far=39  (15069s)
#   scanned 475/576  ESS-so-far=39  (15101s)
#   scanned 476/576  ESS-so-far=39  (15132s)
#   scanned 477/576  ESS-so-far=39  (15163s)
#   scanned 478/576  ESS-so-far=39  (15195s)
#   scanned 479/576  ESS-so-far=39  (15226s)
#   scanned 480/576  ESS-so-far=39  (15258s)
#   scanned 481/576  ESS-so-far=39  (15289s)
# ✓ ESS found at profile #482: sub / minQC / strict / accept / auditM              max_Re(eig)=-0.964  repl_conv=1.00
#   scanned 482/576  ESS-so-far=40  (15321s)
#   scanned 483/576  ESS-so-far=40  (15352s)
# ✓ ESS found at profile #484: sub / minQC / strict / accept / noAudit             max_Re(eig)=-1.159  repl_conv=1.00
#   scanned 484/576  ESS-so-far=41  (15392s)
#   scanned 485/576  ESS-so-far=41  (15424s)
#   scanned 486/576  ESS-so-far=41  (15456s)
#   scanned 487/576  ESS-so-far=41  (15487s)
#   scanned 488/576  ESS-so-far=41  (15519s)
#   scanned 489/576  ESS-so-far=41  (15551s)
#   scanned 490/576  ESS-so-far=41  (15582s)
#   scanned 491/576  ESS-so-far=41  (15614s)
#   scanned 492/576  ESS-so-far=41  (15645s)
#   scanned 493/576  ESS-so-far=41  (15676s)
#   scanned 494/576  ESS-so-far=41  (15708s)
#   scanned 495/576  ESS-so-far=41  (15739s)
#   scanned 496/576  ESS-so-far=41  (15770s)
#   scanned 497/576  ESS-so-far=41  (15802s)
#   scanned 498/576  ESS-so-far=41  (15833s)
#   scanned 499/576  ESS-so-far=41  (15865s)
#   scanned 500/576  ESS-so-far=41  (15896s)
#   scanned 501/576  ESS-so-far=41  (15928s)
#   scanned 502/576  ESS-so-far=41  (15959s)
#   scanned 503/576  ESS-so-far=41  (15991s)
#   scanned 504/576  ESS-so-far=41  (16022s)
#   scanned 505/576  ESS-so-far=41  (16054s)
#   scanned 506/576  ESS-so-far=41  (16085s)
#   scanned 507/576  ESS-so-far=41  (16116s)
#   scanned 508/576  ESS-so-far=41  (16148s)
#   scanned 509/576  ESS-so-far=41  (16179s)
#   scanned 510/576  ESS-so-far=41  (16210s)
#   scanned 511/576  ESS-so-far=41  (16243s)
#   scanned 512/576  ESS-so-far=41  (16275s)
#   scanned 513/576  ESS-so-far=41  (16306s)
#   scanned 514/576  ESS-so-far=41  (16337s)
#   scanned 515/576  ESS-so-far=41  (16368s)
#   scanned 516/576  ESS-so-far=41  (16399s)
#   scanned 517/576  ESS-so-far=41  (16431s)
#   scanned 518/576  ESS-so-far=41  (16462s)
#   scanned 519/576  ESS-so-far=41  (16494s)
#   scanned 520/576  ESS-so-far=41  (16525s)
#   scanned 521/576  ESS-so-far=41  (16556s)
#   scanned 522/576  ESS-so-far=41  (16588s)
#   scanned 523/576  ESS-so-far=41  (16619s)
# ✓ ESS found at profile #524: sub / minQC / slack / return / noAudit              max_Re(eig)=-2.355  repl_conv=1.00
#   scanned 524/576  ESS-so-far=42  (16650s)
#   scanned 525/576  ESS-so-far=42  (16682s)
#   scanned 526/576  ESS-so-far=42  (16713s)
#   scanned 527/576  ESS-so-far=42  (16744s)
#   scanned 528/576  ESS-so-far=42  (16775s)
# ✓ ESS found at profile #529: sub / noQC / strict / accept / auditH               max_Re(eig)=-7.277  repl_conv=1.00
#   scanned 529/576  ESS-so-far=43  (16806s)
#   scanned 530/576  ESS-so-far=43  (16837s)
#   scanned 531/576  ESS-so-far=43  (16869s)
#   scanned 532/576  ESS-so-far=43  (16900s)
#   scanned 533/576  ESS-so-far=43  (16931s)
#   scanned 534/576  ESS-so-far=43  (16962s)
#   scanned 535/576  ESS-so-far=43  (16993s)
#   scanned 536/576  ESS-so-far=43  (17025s)
# ✓ ESS found at profile #537: sub / noQC / strict / return / auditH               max_Re(eig)=-3.701  repl_conv=1.00
#   scanned 537/576  ESS-so-far=44  (17057s)
#   scanned 538/576  ESS-so-far=44  (17088s)
#   scanned 539/576  ESS-so-far=44  (17119s)
#   scanned 540/576  ESS-so-far=44  (17150s)
#   scanned 541/576  ESS-so-far=44  (17181s)
#   scanned 542/576  ESS-so-far=44  (17212s)
#   scanned 543/576  ESS-so-far=44  (17243s)
#   scanned 544/576  ESS-so-far=44  (17274s)
#   scanned 545/576  ESS-so-far=44  (17306s)
#   scanned 546/576  ESS-so-far=44  (17337s)
#   scanned 547/576  ESS-so-far=44  (17368s)
#   scanned 548/576  ESS-so-far=44  (17399s)
#   scanned 549/576  ESS-so-far=44  (17430s)
#   scanned 550/576  ESS-so-far=44  (17461s)
#   scanned 551/576  ESS-so-far=44  (17492s)
#   scanned 552/576  ESS-so-far=44  (17523s)
# ✓ ESS found at profile #553: sub / noQC / sampling / return / auditH             max_Re(eig)=-0.345  repl_conv=1.00
#   scanned 553/576  ESS-so-far=45  (17554s)
#   scanned 554/576  ESS-so-far=45  (17586s)
#   scanned 555/576  ESS-so-far=45  (17619s)
#   scanned 556/576  ESS-so-far=45  (17655s)
#   scanned 557/576  ESS-so-far=45  (17700s)
#   scanned 558/576  ESS-so-far=45  (17737s)
#   scanned 559/576  ESS-so-far=45  (17778s)
#   scanned 560/576  ESS-so-far=45  (17818s)
#   scanned 561/576  ESS-so-far=45  (17859s)
#   scanned 562/576  ESS-so-far=45  (17894s)
#   scanned 563/576  ESS-so-far=45  (17924s)
#   scanned 564/576  ESS-so-far=45  (17953s)
#   scanned 565/576  ESS-so-far=45  (17983s)
#   scanned 566/576  ESS-so-far=45  (18012s)
#   scanned 567/576  ESS-so-far=45  (18047s)
#   scanned 568/576  ESS-so-far=45  (18086s)
# ✓ ESS found at profile #569: sub / noQC / slack / return / auditH                max_Re(eig)=-8.983  repl_conv=1.00
#   scanned 569/576  ESS-so-far=46  (18124s)
#   scanned 570/576  ESS-so-far=46  (18163s)
#   scanned 571/576  ESS-so-far=46  (18201s)
#   scanned 572/576  ESS-so-far=46  (18240s)
#   scanned 573/576  ESS-so-far=46  (18278s)
#   scanned 574/576  ESS-so-far=46  (18317s)
#   scanned 575/576  ESS-so-far=46  (18355s)
#   scanned 576/576  ESS-so-far=46  (18393s)
#
# SCAN DONE: 576 profiles, 46 flagged ESS  (18393s)

# %% [markdown]
# ## 14. Which profiles are ESS (out of 576)
#
# The profiles flagged ESS in the scan. This is the empirical map of which strategy combinations the
# game can sustain as an evolutionarily stable state under the (Option A or C) economics.

# %%
OUTDIR
# Out:
# 'results_5player'

# %%
ess_df = scan_df[scan_df['is_ess']].copy().sort_values('max_re_eig')
pcols = [f'p{i}' for i in range(N_PLAYERS)]
ess_df['profile'] = ess_df[pcols].agg(lambda r: ' / '.join(r.values), axis=1)
ess_df.to_csv(os.path.join(OUTDIR, f'ESS_profiles_{SCAN_METHOD}.csv'), index=False)

print(f"ESS profiles found: {len(ess_df)} / {len(scan_df)}\n")
for _,r in ess_df.iterrows():
    print(f"  {r['profile']:55s}  max_Re(eig)={r['max_re_eig']:+.3f}  repl_conv={r['repl_conv']:.2f}")
ess_df[pcols+['max_re_eig','repl_conv','reward']]
# Out:
# ESS profiles found: 46 / 576
#
#   high / fullQC / strict / accept / auditH                 max_Re(eig)=-10.113  repl_conv=1.00
#   sub / noQC / slack / return / auditH                     max_Re(eig)=-8.983  repl_conv=1.00
#   sub / fullQC / sampling / accept / auditH                max_Re(eig)=-7.500  repl_conv=1.00
#   sub / noQC / strict / accept / auditH                    max_Re(eig)=-7.277  repl_conv=1.00
#   standard / fullQC / sampling / accept / auditH           max_Re(eig)=-6.594  repl_conv=1.00
#   standard / fullQC / slack / accept / auditH              max_Re(eig)=-5.004  repl_conv=1.00
#   high / fullQC / strict / accept / auditM                 max_Re(eig)=-4.972  repl_conv=1.00
#   standard / fullQC / strict / accept / auditL             max_Re(eig)=-4.800  repl_conv=1.00
#   high / partQC / strict / accept / auditH                 max_Re(eig)=-4.696  repl_conv=1.00
#   standard / partQC / sampling / accept / auditH           max_Re(eig)=-4.252  repl_conv=1.00
#   sub / noQC / strict / return / auditH                    max_Re(eig)=-3.701  repl_conv=1.00
#   standard / partQC / strict / accept / auditL             max_Re(eig)=-3.576  repl_conv=1.00
#   standard / partQC / slack / accept / auditH              max_Re(eig)=-3.345  repl_conv=1.00
#   standard / fullQC / sampling / accept / noAudit          max_Re(eig)=-3.115  repl_conv=1.00
#   standard / fullQC / strict / accept / auditM             max_Re(eig)=-2.973  repl_conv=1.00
#   high / fullQC / slack / accept / auditH                  max_Re(eig)=-2.905  repl_conv=1.00
#   standard / fullQC / sampling / accept / auditL           max_Re(eig)=-2.896  repl_conv=1.00
#   high / minQC / strict / accept / auditM                  max_Re(eig)=-2.572  repl_conv=1.00
#   high / fullQC / sampling / accept / auditM               max_Re(eig)=-2.458  repl_conv=1.00
#   sub / minQC / slack / return / noAudit                   max_Re(eig)=-2.355  repl_conv=1.00
#   sub / partQC / strict / accept / auditM                  max_Re(eig)=-2.151  repl_conv=1.00
#   standard / partQC / strict / accept / noAudit            max_Re(eig)=-2.091  repl_conv=1.00
#   standard / minQC / strict / accept / noAudit             max_Re(eig)=-2.057  repl_conv=1.00
#   high / fullQC / strict / accept / noAudit                max_Re(eig)=-1.882  repl_conv=1.00
#   standard / fullQC / strict / accept / auditH             max_Re(eig)=-1.845  repl_conv=1.00
#   high / fullQC / strict / accept / auditL                 max_Re(eig)=-1.818  repl_conv=1.00
#   sub / partQC / slack / return / auditH                   max_Re(eig)=-1.616  repl_conv=1.00
#   standard / partQC / slack / reinspect / auditH           max_Re(eig)=-1.590  repl_conv=1.00
#   high / partQC / sampling / accept / auditH               max_Re(eig)=-1.417  repl_conv=1.00
#   standard / partQC / strict / accept / auditM             max_Re(eig)=-1.285  repl_conv=1.00
#   sub / partQC / strict / return / auditL                  max_Re(eig)=-1.226  repl_conv=1.00
#   sub / minQC / strict / accept / noAudit                  max_Re(eig)=-1.159  repl_conv=1.00
#   standard / minQC / strict / accept / auditM              max_Re(eig)=-1.148  repl_conv=1.00
#   standard / partQC / sampling / accept / auditL           max_Re(eig)=-1.033  repl_conv=1.00
#   high / partQC / sampling / accept / noAudit              max_Re(eig)=-1.015  repl_conv=1.00
#   standard / fullQC / strict / accept / noAudit            max_Re(eig)=-1.004  repl_conv=1.00
#   high / minQC / strict / accept / auditL                  max_Re(eig)=-0.977  repl_conv=1.00
#   sub / minQC / strict / accept / auditM                   max_Re(eig)=-0.964  repl_conv=1.00
#   standard / fullQC / slack / return / auditM              max_Re(eig)=-0.922  repl_conv=1.00
#   high / fullQC / sampling / accept / auditH               max_Re(eig)=-0.644  repl_conv=1.00
#   high / fullQC / sampling / accept / noAudit              max_Re(eig)=-0.616  repl_conv=1.00
#   sub / fullQC / strict / return / auditH                  max_Re(eig)=-0.603  repl_conv=1.00
#   standard / fullQC / sampling / accept / auditM           max_Re(eig)=-0.523  repl_conv=1.00
#   sub / noQC / sampling / return / auditH                  max_Re(eig)=-0.345  repl_conv=1.00
#   high / partQC / sampling / accept / auditM               max_Re(eig)=-0.333  repl_conv=1.00
#   sub / fullQC / sampling / return / noAudit               max_Re(eig)=-0.087  repl_conv=1.00
#            p0      p1        p2         p3       p4  max_re_eig  repl_conv  \
# 0        high  fullQC    strict     accept   auditH  -10.113062        1.0
# 568       sub    noQC     slack     return   auditH   -8.983005        1.0
# 400       sub  fullQC  sampling     accept   auditH   -7.500431        1.0
# 528       sub    noQC    strict     accept   auditH   -7.277016        1.0
# 208  standard  fullQC  sampling     accept   auditH   -6.593720        1.0
# 224  standard  fullQC     slack     accept   auditH   -5.003558        1.0
# 1        high  fullQC    strict     accept   auditM   -4.971711        1.0
# 194  standard  fullQC    strict     accept   auditL   -4.799576        1.0
# 48       high  partQC    strict     accept   auditH   -4.695594        1.0
# 256  standard  partQC  sampling     accept   auditH   -4.251835        1.0
# 536       sub    noQC    strict     return   auditH   -3.700533        1.0
# 242  standard  partQC    strict     accept   auditL   -3.576323        1.0
# 272  standard  partQC     slack     accept   auditH   -3.345486        1.0
# 211  standard  fullQC  sampling     accept  noAudit   -3.114920        1.0
# 193  standard  fullQC    strict     accept   auditM   -2.972726        1.0
# 32       high  fullQC     slack     accept   auditH   -2.904668        1.0
# 210  standard  fullQC  sampling     accept   auditL   -2.895978        1.0
# 97       high   minQC    strict     accept   auditM   -2.571545        1.0
# 17       high  fullQC  sampling     accept   auditM   -2.458286        1.0
# 523       sub   minQC     slack     return  noAudit   -2.355421        1.0
# 433       sub  partQC    strict     accept   auditM   -2.151157        1.0
# 243  standard  partQC    strict     accept  noAudit   -2.090814        1.0
# 291  standard   minQC    strict     accept  noAudit   -2.057142        1.0
# 3        high  fullQC    strict     accept  noAudit   -1.882138        1.0
# 192  standard  fullQC    strict     accept   auditH   -1.844624        1.0
# 2        high  fullQC    strict     accept   auditL   -1.817750        1.0
# 472       sub  partQC     slack     return   auditH   -1.616055        1.0
# 276  standard  partQC     slack  reinspect   auditH   -1.590231        1.0
# 64       high  partQC  sampling     accept   auditH   -1.416761        1.0
# 241  standard  partQC    strict     accept   auditM   -1.285419        1.0
# 442       sub  partQC    strict     return   auditL   -1.226305        1.0
# 483       sub   minQC    strict     accept  noAudit   -1.158608        1.0
# 289  standard   minQC    strict     accept   auditM   -1.147584        1.0
# 258  standard  partQC  sampling     accept   auditL   -1.032502        1.0
# 67       high  partQC  sampling     accept  noAudit   -1.014581        1.0
# 195  standard  fullQC    strict     accept  noAudit   -1.004027        1.0
# 98       high   minQC    strict     accept   auditL   -0.976928        1.0
# 481       sub   minQC    strict     accept   auditM   -0.963579        1.0
# 233  standard  fullQC     slack     return   auditM   -0.922302        1.0
# 16       high  fullQC  sampling     accept   auditH   -0.643944        1.0
# 19       high  fullQC  sampling     accept  noAudit   -0.615823        1.0
# 392       sub  fullQC    strict     return   auditH   -0.603051        1.0
# 209  standard  fullQC  sampling     accept   auditM   -0.523403        1.0
# 552       sub    noQC  sampling     return   auditH   -0.344882        1.0
# 65       high  partQC  sampling     accept   auditM   -0.333250        1.0
# 411       sub  fullQC  sampling     return  noAudit   -0.086549        1.0
#
#        reward
# 0   -0.019276
# 568 -0.009855
# 400 -0.053991
# 528 -0.120685
# 208 -0.034041
# 224 -0.102415
# 1   -0.047650
# 194 -0.134745
# 48  -0.105225
# 256 -0.113409
# 536 -3.646700
# 242 -0.111046
# 272 -0.095746
# 211 -0.205077
# 193 -0.036392
# 32  -0.724854
# 210 -0.082385
# 97  -0.297378
# 17  -0.286388
# 523 -0.160698
# 433 -0.129144
# 243 -0.092517
# 291 -0.054296
# 3   -0.726499
# 192 -0.039922
# 2   -0.113255
# 472 -0.879344
# 276 -0.423066
# 64  -0.108014
# 241 -0.243753
# 442 -0.157680
# 483 -0.036099
# 289 -0.097273
# 258 -0.152244
# 67  -3.416947
# 195 -0.078795
# 98  -0.265830
# 481 -0.184163
# 233 -0.569838
# 16  -0.066360
# 19  -0.472674
# 392 -0.031873
# 209 -0.193693
# 552 -2.643475
# 65  -0.209654
# 411 -0.167263

# %% [markdown]
# ## 15. Full run: 100 searches per ESS profile, strict success
#
# For each profile the scan flagged ESS, we now run the **full 100-run** experiment and report
# **strict success** (a run counts only if all validation replicator starts converge, `repl_conv == 1.0`).
# Uses `CFG` paper-scale settings. Results per profile saved to CSV; a combined summary is written at the end.

# %%
def full_run_profile(choices, label):
    target = onehot_target(choices)
    if SCAN_METHOD=='SAC':
        df = sac_search(target, n_runs=CFG['N_RUNS'], n_steps=CFG['N_OUTER'], n_episodes=CFG['N_EPISODES'],
                        use_early_stopping=False, patience=CFG['PATIENCE'], seed0=1, verbose_every=25)
    else:
        df = bo_search(target, n_runs=CFG['N_RUNS'], n_calls=min(CFG['N_OUTER'],60),
                       n_episodes=CFG['N_EPISODES'], seed0=1)
    save_csv(df.drop(columns=['profile']), f"optimal_parameters_{SCAN_METHOD}_{label}.csv")
    # validate each run with the scan-level replicator budget
    rows=[]
    for _,r in df.iterrows():
        th={n:float(r[n]) for n in PARAM_NAMES}
        conv=simulate_replicator(th, np.array(target), n_starts=N_VAL_SCAN)
        eigs,allneg=numerical_jacobian_eigs(th, np.array(target))
        rows.append(dict(run_id=int(r['run_id']), repl_conv=conv,
                         strict_pass=bool(conv>=1.0), all_eig_neg=bool(allneg),
                         max_re_eig=float(np.max(eigs.real))))
    val=pd.DataFrame(rows); save_csv(val, f"validation_{SCAN_METHOD}_{label}.csv")
    strict=100.0*val['strict_pass'].mean()
    return dict(profile=label, n_runs=len(val),
                strict_success_pct=round(strict,2),
                pct_fully_converged=round(strict,2),
                mean_repl_conv=round(val['repl_conv'].mean(),4),
                pct_all_eig_negative=round(100.0*val['all_eig_neg'].mean(),2))

summaries=[]
for _,r in ess_df.iterrows():
    choices=[r[f'p{i}'] for i in range(N_PLAYERS)]
    label='_'.join(choices)
    print(f"\n=== FULL 100-run for ESS profile: {label} ===")
    summaries.append(full_run_profile(choices, label))

if summaries:
    full_summary=pd.DataFrame(summaries).sort_values('strict_success_pct', ascending=False)
    full_summary.to_csv(os.path.join(OUTDIR, f'ESS_full_summary_{SCAN_METHOD}.csv'), index=False)
    print("\n===== FULL-RUN STRICT SUCCESS (per ESS profile) =====")
    print(full_summary.to_string(index=False))
else:
    print("No ESS profiles were flagged in the scan; nothing to run at full scale.")

# %% [markdown]
# ## 16. Notes
#
# - **Two phases:** (1) scan all 576 profiles with one search each + `N_VAL_SCAN` replicator validation to find which are ESS; (2) run 100 searches on each ESS profile with strict-success reporting.
# - **Option A vs C:** set `USE_OPTION_C` in Section 11. Option A = original payoff with wider bounds; Option C = original + incentive levers (Vq, G, Sc) so good-governance profiles can be ESS.
# - **Validation starts** are `N_VAL_SCAN = N_VAL_STARTS + 10` throughout, as requested.
# - **Cost:** the 576-scan is the expensive part; run it once on a GPU. All CSVs are saved so the full-run phase can reuse the ESS list.
# - **Honesty:** a profile only appears as ESS if the search actually found stabilizing parameters AND validation confirms it (eigenvalues negative + all replicator starts converge). Profiles with no ESS under the chosen economics will simply not appear.
