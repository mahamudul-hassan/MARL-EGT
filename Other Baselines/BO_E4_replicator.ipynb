# %%
"""
run_BO_E4.py  -- Bayesian Optimization (Optuna/TPE) with REPLICATOR-simulation
fitness (same objective as GA / PSO / NSGA-II) for equilibrium E4.
Does N_RUNS (=100) runs. Writes BO_E4_all_runs.csv, BO_E4_summary.csv,
BO_E4_eigenvalues.csv into metaheuristics_results/.

Run in its own process/notebook:
    python run_BO_E4.py
"""
import time
from egt_common import N_RUNS
from bo_replicator import run_bo_single_eq

# BO trials per run. Each trial = one replicator-fitness evaluation (N_FIT_SEEDS
# replicator sims). 200 mirrors the n_bo_trials used in the PPO-based BO notebook.
N_BO_TRIALS = 100
MASTER_SEED = 42

if __name__ == '__main__':
    t0 = time.time()
    run_bo_single_eq('E4', n_runs=N_RUNS, n_bo_trials=N_BO_TRIALS,
                     master_seed=MASTER_SEED)
    print(f"\nBO E4 done in {(time.time()-t0)/60:.1f} min")
# Out:
# ...
#   BO (replicator fitness)  |  E4 (Genuine, Accept, Slack)  target=(1, 1, 0)  (stable)
# ...
#   runs=100  BO trials/run=100  fit seeds=5  val seeds=5
#   Run   1/100 +  fit=1.00  conv=1.00  allNegEig=True  t=21.4s
#   Run   2/100 +  fit=1.00  conv=1.00  allNegEig=True  t=25.1s
#   Run   3/100 +  fit=1.00  conv=1.00  allNegEig=True  t=26.3s
#   Run   4/100 +  fit=1.00  conv=1.00  allNegEig=True  t=24.9s
#   Run   5/100 +  fit=1.00  conv=1.00  allNegEig=True  t=22.6s
#   Run   6/100 +  fit=1.00  conv=1.00  allNegEig=True  t=22.4s
#   Run   7/100 +  fit=1.00  conv=1.00  allNegEig=True  t=23.1s
#   Run   8/100 +  fit=1.00  conv=1.00  allNegEig=True  t=23.0s
#   Run   9/100 +  fit=1.00  conv=1.00  allNegEig=True  t=23.7s
#   Run  10/100 +  fit=1.00  conv=1.00  allNegEig=True  t=23.7s
#   Run  11/100 +  fit=1.00  conv=1.00  allNegEig=True  t=25.3s
#   Run  12/100 +  fit=1.00  conv=1.00  allNegEig=True  t=22.1s
#   Run  13/100 ~  fit=1.00  conv=0.40  allNegEig=True  t=25.0s
# ...
